# %%
# Libraries you should have installed:"
# twilio
# pandas
# requests
# tqdm

from twilio.rest import Client
import time
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd
import requests
from bs4  import BeautifulSoup
from tqdm import tqdm

from datetime import datetime

# %%
# Location for which you want to check the forecast
query = 'London' # !!!

api_key = 'YOUR WEATHERAPI KEY' # !!!

url = 'http://api.weatherapi.com/v1/forecast.json?key='+api_key+'&q='+query+'&days=1&aqi=no&alerts=no'

# %% [markdown]
# API call

# %%
response = requests.get(url).json()

# %%
response
# Out:
# {'location': {'name': 'London',
#   'region': 'City of London, Greater London',
#   'country': 'United Kingdom',
#   'lat': 51.52,
#   'lon': -0.11,
#   'tz_id': 'Europe/London',
#   'localtime_epoch': 1697306825,
#   'localtime': '2023-10-14 19:07'},
#  'current': {'last_updated_epoch': 1697306400,
#   'last_updated': '2023-10-14 19:00',
#   'temp_c': 9.0,
#   'temp_f': 48.2,
#   'is_day': 0,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#    'code': 1003},
#   'wind_mph': 8.1,
#   'wind_kph': 13.0,
#   'wind_degree': 280,
#   'wind_dir': 'W',
#   'pressure_mb': 1020.0,
#   'pressure_in': 30.12,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 81,
#   'cloud': 25,
#   'feelslike_c': 7.4,
#   'feelslike_f': 45.2,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 1.0,
#   'gust_mph': 9.4,
#   'gust_kph': 15.2},
#  'forecast': {'forecastday': [{'date': '2023-10-14',
#     'date_epoch': 1697241600,
#     'day': {'maxtemp_c': 13.8,
#      'maxtemp_f': 56.8,
#      'mintemp_c': 9.1,
#      'mintemp_f': 48.3,
#      'avgtemp_c': 11.1,
#      'avgtemp_f': 51.9,
#      'maxwind_mph': 12.5,
#      'maxwind_kph': 20.2,
#      'totalprecip_mm': 0.06,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 65.0,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 0,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Sunny',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#       'code': 1000},
#      'uv': 4.0},
#     'astro': {'sunrise': '07:22 AM',
#      'sunset': '06:10 PM',
#      'moonrise': '06:53 AM',
#      'moonset': '06:05 PM',
#      'moon_phase': 'New Moon',
#      'moon_illumination': '1',
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1697238000,
#       'time': '2023-10-14 00:00',
#       'temp_c': 10.5,
#       'temp_f': 50.8,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 12.5,
#       'wind_kph': 20.2,
#       'wind_degree': 294,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.78,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 2,
#       'feelslike_c': 8.0,
#       'feelslike_f': 46.3,
#       'windchill_c': 8.0,
#       'windchill_f': 46.3,
#       'heatindex_c': 10.5,
#       'heatindex_f': 50.8,
#       'dewpoint_c': 6.2,
#       'dewpoint_f': 43.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.8,
#       'gust_kph': 28.7,
#       'uv': 1.0},
#      {'time_epoch': 1697241600,
#       'time': '2023-10-14 01:00',
#       'temp_c': 10.2,
#       'temp_f': 50.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 292,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.82,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 2,
#       'feelslike_c': 7.7,
#       'feelslike_f': 45.9,
#       'windchill_c': 7.7,
#       'windchill_f': 45.9,
#       'heatindex_c': 10.2,
#       'heatindex_f': 50.4,
#       'dewpoint_c': 6.1,
#       'dewpoint_f': 43.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.0,
#       'gust_kph': 27.4,
#       'uv': 1.0},
#      {'time_epoch': 1697245200,
#       'time': '2023-10-14 02:00',
#       'temp_c': 10.0,
#       'temp_f': 49.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 290,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1011.0,
#       'pressure_in': 29.85,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 3,
#       'feelslike_c': 7.5,
#       'feelslike_f': 45.5,
#       'windchill_c': 7.5,
#       'windchill_f': 45.5,
#       'heatindex_c': 10.0,
#       'heatindex_f': 49.9,
#       'dewpoint_c': 6.0,
#       'dewpoint_f': 42.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.2,
#       'gust_kph': 26.0,
#       'uv': 1.0},
#      {'time_epoch': 1697248800,
#       'time': '2023-10-14 03:00',
#       'temp_c': 9.8,
#       'temp_f': 49.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 285,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 4,
#       'feelslike_c': 7.5,
#       'feelslike_f': 45.5,
#       'windchill_c': 7.5,
#       'windchill_f': 45.5,
#       'heatindex_c': 9.8,
#       'heatindex_f': 49.7,
#       'dewpoint_c': 6.3,
#       'dewpoint_f': 43.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.9,
#       'gust_kph': 23.9,
#       'uv': 1.0},
#      {'time_epoch': 1697252400,
#       'time': '2023-10-14 04:00',
#       'temp_c': 9.7,
#       'temp_f': 49.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 279,
#       'wind_dir': 'W',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 5,
#       'feelslike_c': 7.5,
#       'feelslike_f': 45.4,
#       'windchill_c': 7.5,
#       'windchill_f': 45.4,
#       'heatindex_c': 9.7,
#       'heatindex_f': 49.4,
#       'dewpoint_c': 6.1,
#       'dewpoint_f': 42.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.9,
#       'gust_kph': 22.3,
#       'uv': 1.0},
#      {'time_epoch': 1697256000,
#       'time': '2023-10-14 05:00',
#       'temp_c': 9.4,
#       'temp_f': 49.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 9.4,
#       'wind_kph': 15.1,
#       'wind_degree': 276,
#       'wind_dir': 'W',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 8,
#       'feelslike_c': 7.2,
#       'feelslike_f': 45.0,
#       'windchill_c': 7.2,
#       'windchill_f': 45.0,
#       'heatindex_c': 9.5,
#       'heatindex_f': 49.0,
#       'dewpoint_c': 5.9,
#       'dewpoint_f': 42.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.6,
#       'gust_kph': 21.9,
#       'uv': 1.0},
#      {'time_epoch': 1697259600,
#       'time': '2023-10-14 06:00',
#       'temp_c': 9.3,
#       'temp_f': 48.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 273,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 78,
#       'cloud': 10,
#       'feelslike_c': 7.1,
#       'feelslike_f': 44.8,
#       'windchill_c': 7.1,
#       'windchill_f': 44.8,
#       'heatindex_c': 9.3,
#       'heatindex_f': 48.7,
#       'dewpoint_c': 5.6,
#       'dewpoint_f': 42.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.1,
#       'gust_kph': 21.1,
#       'uv': 1.0},
#      {'time_epoch': 1697263200,
#       'time': '2023-10-14 07:00',
#       'temp_c': 9.3,
#       'temp_f': 48.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 270,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 14,
#       'feelslike_c': 7.3,
#       'feelslike_f': 45.2,
#       'windchill_c': 7.3,
#       'windchill_f': 45.2,
#       'heatindex_c': 9.3,
#       'heatindex_f': 48.7,
#       'dewpoint_c': 5.5,
#       'dewpoint_f': 42.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.5,
#       'gust_kph': 18.6,
#       'uv': 1.0},
#      {'time_epoch': 1697266800,
#       'time': '2023-10-14 08:00',
#       'temp_c': 10.0,
#       'temp_f': 50.0,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 272,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 74,
#       'cloud': 26,
#       'feelslike_c': 8.0,
#       'feelslike_f': 46.3,
#       'windchill_c': 8.0,
#       'windchill_f': 46.3,
#       'heatindex_c': 10.0,
#       'heatindex_f': 50.0,
#       'dewpoint_c': 5.5,
#       'dewpoint_f': 42.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.2,
#       'gust_kph': 19.6,
#       'uv': 4.0},
#      {'time_epoch': 1697270400,
#       'time': '2023-10-14 09:00',
#       'temp_c': 11.2,
#       'temp_f': 52.1,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 291,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'humidity': 69,
#       'cloud': 71,
#       'feelslike_c': 9.3,
#       'feelslike_f': 48.7,
#       'windchill_c': 9.3,
#       'windchill_f': 48.7,
#       'heatindex_c': 11.2,
#       'heatindex_f': 52.1,
#       'dewpoint_c': 5.7,
#       'dewpoint_f': 42.2,
#       'will_it_rain': 1,
#       'chance_of_rain': 72,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.2,
#       'gust_kph': 19.6,
#       'uv': 3.0},
#      {'time_epoch': 1697274000,
#       'time': '2023-10-14 10:00',
#       'temp_c': 12.0,
#       'temp_f': 53.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 296,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 62,
#       'cloud': 20,
#       'feelslike_c': 10.3,
#       'feelslike_f': 50.5,
#       'windchill_c': 10.3,
#       'windchill_f': 50.5,
#       'heatindex_c': 12.0,
#       'heatindex_f': 53.5,
#       'dewpoint_c': 4.9,
#       'dewpoint_f': 40.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.2,
#       'gust_kph': 18.0,
#       'uv': 4.0},
#      {'time_epoch': 1697277600,
#       'time': '2023-10-14 11:00',
#       'temp_c': 12.8,
#       'temp_f': 55.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 306,
#       'wind_dir': 'NW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 55,
#       'cloud': 24,
#       'feelslike_c': 11.2,
#       'feelslike_f': 52.2,
#       'windchill_c': 11.2,
#       'windchill_f': 52.2,
#       'heatindex_c': 12.8,
#       'heatindex_f': 55.0,
#       'dewpoint_c': 3.9,
#       'dewpoint_f': 39.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.6,
#       'gust_kph': 18.6,
#       'uv': 4.0},
#      {'time_epoch': 1697281200,
#       'time': '2023-10-14 12:00',
#       'temp_c': 13.4,
#       'temp_f': 56.0,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 309,
#       'wind_dir': 'NW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 66,
#       'feelslike_c': 11.9,
#       'feelslike_f': 53.4,
#       'windchill_c': 11.9,
#       'windchill_f': 53.4,
#       'heatindex_c': 13.4,
#       'heatindex_f': 56.0,
#       'dewpoint_c': 3.5,
#       'dewpoint_f': 38.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 81,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.1,
#       'gust_kph': 19.5,
#       'uv': 3.0},
#      {'time_epoch': 1697284800,
#       'time': '2023-10-14 13:00',
#       'temp_c': 13.7,
#       'temp_f': 56.6,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 309,
#       'wind_dir': 'NW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 48,
#       'cloud': 67,
#       'feelslike_c': 12.3,
#       'feelslike_f': 54.1,
#       'windchill_c': 12.3,
#       'windchill_f': 54.1,
#       'heatindex_c': 13.7,
#       'heatindex_f': 56.6,
#       'dewpoint_c': 2.9,
#       'dewpoint_f': 37.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 83,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.8,
#       'gust_kph': 19.0,
#       'uv': 3.0},
#      {'time_epoch': 1697288400,
#       'time': '2023-10-14 14:00',
#       'temp_c': 13.8,
#       'temp_f': 56.8,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 310,
#       'wind_dir': 'NW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 46,
#       'cloud': 63,
#       'feelslike_c': 12.5,
#       'feelslike_f': 54.5,
#       'windchill_c': 12.5,
#       'windchill_f': 54.5,
#       'heatindex_c': 13.8,
#       'heatindex_f': 56.8,
#       'dewpoint_c': 2.5,
#       'dewpoint_f': 36.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 78,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.3,
#       'gust_kph': 18.2,
#       'uv': 3.0},
#      {'time_epoch': 1697292000,
#       'time': '2023-10-14 15:00',
#       'temp_c': 13.5,
#       'temp_f': 56.4,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 306,
#       'wind_dir': 'NW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.08,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 46,
#       'cloud': 56,
#       'feelslike_c': 12.1,
#       'feelslike_f': 53.8,
#       'windchill_c': 12.1,
#       'windchill_f': 53.8,
#       'heatindex_c': 13.5,
#       'heatindex_f': 56.4,
#       'dewpoint_c': 2.3,
#       'dewpoint_f': 36.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 87,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.5,
#       'gust_kph': 20.2,
#       'uv': 3.0},
#      {'time_epoch': 1697295600,
#       'time': '2023-10-14 16:00',
#       'temp_c': 13.1,
#       'temp_f': 55.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 310,
#       'wind_dir': 'NW',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 48,
#       'cloud': 20,
#       'feelslike_c': 11.6,
#       'feelslike_f': 53.0,
#       'windchill_c': 11.6,
#       'windchill_f': 53.0,
#       'heatindex_c': 13.1,
#       'heatindex_f': 55.5,
#       'dewpoint_c': 2.3,
#       'dewpoint_f': 36.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.3,
#       'gust_kph': 19.8,
#       'uv': 4.0},
#      {'time_epoch': 1697299200,
#       'time': '2023-10-14 17:00',
#       'temp_c': 12.2,
#       'temp_f': 54.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 308,
#       'wind_dir': 'NW',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.11,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 52,
#       'cloud': 9,
#       'feelslike_c': 11.1,
#       'feelslike_f': 51.9,
#       'windchill_c': 11.1,
#       'windchill_f': 51.9,
#       'heatindex_c': 12.2,
#       'heatindex_f': 54.0,
#       'dewpoint_c': 2.8,
#       'dewpoint_f': 37.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.2,
#       'gust_kph': 16.5,
#       'uv': 4.0},
#      {'time_epoch': 1697302800,
#       'time': '2023-10-14 18:00',
#       'temp_c': 11.6,
#       'temp_f': 52.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 312,
#       'wind_dir': 'NW',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.13,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 56,
#       'cloud': 18,
#       'feelslike_c': 10.4,
#       'feelslike_f': 50.8,
#       'windchill_c': 10.4,
#       'windchill_f': 50.8,
#       'heatindex_c': 11.6,
#       'heatindex_f': 52.8,
#       'dewpoint_c': 3.2,
#       'dewpoint_f': 37.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.4,
#       'gust_kph': 15.2,
#       'uv': 4.0},
#      {'time_epoch': 1697306400,
#       'time': '2023-10-14 19:00',
#       'temp_c': 9.0,
#       'temp_f': 48.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 280,
#       'wind_dir': 'W',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.12,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 25,
#       'feelslike_c': 9.8,
#       'feelslike_f': 49.6,
#       'windchill_c': 9.8,
#       'windchill_f': 49.6,
#       'heatindex_c': 11.0,
#       'heatindex_f': 51.9,
#       'dewpoint_c': 3.4,
#       'dewpoint_f': 38.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.4,
#       'gust_kph': 15.2,
#       'uv': 1.0},
#      {'time_epoch': 1697310000,
#       'time': '2023-10-14 20:00',
#       'temp_c': 10.6,
#       'temp_f': 51.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 306,
#       'wind_dir': 'NW',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.16,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 62,
#       'cloud': 8,
#       'feelslike_c': 9.2,
#       'feelslike_f': 48.5,
#       'windchill_c': 9.2,
#       'windchill_f': 48.5,
#       'heatindex_c': 10.6,
#       'heatindex_f': 51.0,
#       'dewpoint_c': 3.7,
#       'dewpoint_f': 38.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.5,
#       'gust_kph': 15.3,
#       'uv': 1.0},
#      {'time_epoch': 1697313600,
#       'time': '2023-10-14 21:00',
#       'temp_c': 10.0,
#       'temp_f': 49.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 307,
#       'wind_dir': 'NW',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.17,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 65,
#       'cloud': 8,
#       'feelslike_c': 8.5,
#       'feelslike_f': 47.3,
#       'windchill_c': 8.5,
#       'windchill_f': 47.3,
#       'heatindex_c': 10.0,
#       'heatindex_f': 49.9,
#       'dewpoint_c': 3.8,
#       'dewpoint_f': 38.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.2,
#       'gust_kph': 14.8,
#       'uv': 1.0},
#      {'time_epoch': 1697317200,
#       'time': '2023-10-14 22:00',
#       'temp_c': 9.5,
#       'temp_f': 49.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 296,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.19,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 67,
#       'cloud': 12,
#       'feelslike_c': 8.0,
#       'feelslike_f': 46.3,
#       'windchill_c': 8.0,
#       'windchill_f': 46.3,
#       'heatindex_c': 9.5,
#       'heatindex_f': 49.1,
#       'dewpoint_c': 3.8,
#       'dewpoint_f': 38.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.2,
#       'gust_kph': 14.8,
#       'uv': 1.0},
#      {'time_epoch': 1697320800,
#       'time': '2023-10-14 23:00',
#       'temp_c': 9.1,
#       'temp_f': 48.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 295,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1023.0,
#       'pressure_in': 30.2,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 69,
#       'cloud': 10,
#       'feelslike_c': 7.4,
#       'feelslike_f': 45.3,
#       'windchill_c': 7.4,
#       'windchill_f': 45.3,
#       'heatindex_c': 9.1,
#       'heatindex_f': 48.3,
#       'dewpoint_c': 3.8,
#       'dewpoint_f': 38.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.5,
#       'gust_kph': 15.2,
#       'uv': 1.0}]}]}}

# %% [markdown]
# Obtaining the keys from the JSON: this is a good practice when working with JSON to make navigation easier

# %%
response.keys()
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %% [markdown]
# The same inside forecastday and its value 0, which is the hour (after exploring the JSON, we arrived at this deduction)

# %%
response['forecast']['forecastday'][0].keys()
# Out:
# dict_keys(['date', 'date_epoch', 'day', 'astro', 'hour'])

# %%
response['forecast']['forecastday'][0]['hour']
# Out:
# [{'time_epoch': 1697238000,
#   'time': '2023-10-14 00:00',
#   'temp_c': 10.5,
#   'temp_f': 50.8,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 12.5,
#   'wind_kph': 20.2,
#   'wind_degree': 294,
#   'wind_dir': 'WNW',
#   'pressure_mb': 1008.0,
#   'pressure_in': 29.78,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 75,
#   'cloud': 2,
#   'feelslike_c': 8.0,
#   'feelslike_f': 46.3,
#   'windchill_c': 8.0,
#   'windchill_f': 46.3,
#   'heatindex_c': 10.5,
#   'heatindex_f': 50.8,
#   'dewpoint_c': 6.2,
#   'dewpoint_f': 43.2,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 17.8,
#   'gust_kph': 28.7,
#   'uv': 1.0},
#  {'time_epoch': 1697241600,
#   'time': '2023-10-14 01:00',
#   'temp_c': 10.2,
#   'temp_f': 50.4,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 11.9,
#   'wind_kph': 19.1,
#   'wind_degree': 292,
#   'wind_dir': 'WNW',
#   'pressure_mb': 1010.0,
#   'pressure_in': 29.82,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 76,
#   'cloud': 2,
#   'feelslike_c': 7.7,
#   'feelslike_f': 45.9,
#   'windchill_c': 7.7,
#   'windchill_f': 45.9,
#   'heatindex_c': 10.2,
#   'heatindex_f': 50.4,
#   'dewpoint_c': 6.1,
#   'dewpoint_f': 43.0,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 17.0,
#   'gust_kph': 27.4,
#   'uv': 1.0},
#  {'time_epoch': 1697245200,
#   'time': '2023-10-14 02:00',
#   'temp_c': 10.0,
#   'temp_f': 49.9,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 11.2,
#   'wind_kph': 18.0,
#   'wind_degree': 290,
#   'wind_dir': 'WNW',
#   'pressure_mb': 1011.0,
#   'pressure_in': 29.85,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 76,
#   'cloud': 3,
#   'feelslike_c': 7.5,
#   'feelslike_f': 45.5,
#   'windchill_c': 7.5,
#   'windchill_f': 45.5,
#   'heatindex_c': 10.0,
#   'heatindex_f': 49.9,
#   'dewpoint_c': 6.0,
#   'dewpoint_f': 42.8,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 16.2,
#   'gust_kph': 26.0,
#   'uv': 1.0},
#  {'time_epoch': 1697248800,
#   'time': '2023-10-14 03:00',
#   'temp_c': 9.8,
#   'temp_f': 49.7,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 10.3,
#   'wind_kph': 16.6,
#   'wind_degree': 285,
#   'wind_dir': 'WNW',
#   'pressure_mb': 1012.0,
#   'pressure_in': 29.88,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 79,
#   'cloud': 4,
#   'feelslike_c': 7.5,
#   'feelslike_f': 45.5,
#   'windchill_c': 7.5,
#   'windchill_f': 45.5,
#   'heatindex_c': 9.8,
#   'heatindex_f': 49.7,
#   'dewpoint_c': 6.3,
#   'dewpoint_f': 43.4,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 14.9,
#   'gust_kph': 23.9,
#   'uv': 1.0},
#  {'time_epoch': 1697252400,
#   'time': '2023-10-14 04:00',
#   'temp_c': 9.7,
#   'temp_f': 49.4,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 9.6,
#   'wind_kph': 15.5,
#   'wind_degree': 279,
#   'wind_dir': 'W',
#   'pressure_mb': 1013.0,
#   'pressure_in': 29.91,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 78,
#   'cloud': 5,
#   'feelslike_c': 7.5,
#   'feelslike_f': 45.4,
#   'windchill_c': 7.5,
#   'windchill_f': 45.4,
#   'heatindex_c': 9.7,
#   'heatindex_f': 49.4,
#   'dewpoint_c': 6.1,
#   'dewpoint_f': 42.9,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 13.9,
#   'gust_kph': 22.3,
#   'uv': 1.0},
#  {'time_epoch': 1697256000,
#   'time': '2023-10-14 05:00',
#   'temp_c': 9.4,
#   'temp_f': 49.0,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 9.4,
#   'wind_kph': 15.1,
#   'wind_degree': 276,
#   'wind_dir': 'W',
#   'pressure_mb': 1014.0,
#   'pressure_in': 29.94,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 78,
#   'cloud': 8,
#   'feelslike_c': 7.2,
#   'feelslike_f': 45.0,
#   'windchill_c': 7.2,
#   'windchill_f': 45.0,
#   'heatindex_c': 9.5,
#   'heatindex_f': 49.0,
#   'dewpoint_c': 5.9,
#   'dewpoint_f': 42.6,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 13.6,
#   'gust_kph': 21.9,
#   'uv': 1.0},
#  {'time_epoch': 1697259600,
#   'time': '2023-10-14 06:00',
#   'temp_c': 9.3,
#   'temp_f': 48.7,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 8.9,
#   'wind_kph': 14.4,
#   'wind_degree': 273,
#   'wind_dir': 'W',
#   'pressure_mb': 1015.0,
#   'pressure_in': 29.96,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 78,
#   'cloud': 10,
#   'feelslike_c': 7.1,
#   'feelslike_f': 44.8,
#   'windchill_c': 7.1,
#   'windchill_f': 44.8,
#   'heatindex_c': 9.3,
#   'heatindex_f': 48.7,
#   'dewpoint_c': 5.6,
#   'dewpoint_f': 42.1,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 13.1,
#   'gust_kph': 21.1,
#   'uv': 1.0},
#  {'time_epoch': 1697263200,
#   'time': '2023-10-14 07:00',
#   'temp_c': 9.3,
#   'temp_f': 48.7,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 8.1,
#   'wind_kph': 13.0,
#   'wind_degree': 270,
#   'wind_dir': 'W',
#   'pressure_mb': 1015.0,
#   'pressure_in': 29.98,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 77,
#   'cloud': 14,
#   'feelslike_c': 7.3,
#   'feelslike_f': 45.2,
#   'windchill_c': 7.3,
#   'windchill_f': 45.2,
#   'heatindex_c': 9.3,
#   'heatindex_f': 48.7,
#   'dewpoint_c': 5.5,
#   'dewpoint_f': 42.0,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 11.5,
#   'gust_kph': 18.6,
#   'uv': 1.0},
#  {'time_epoch': 1697266800,
#   'time': '2023-10-14 08:00',
#   'temp_c': 10.0,
#   'temp_f': 50.0,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 9.2,
#   'wind_kph': 14.8,
#   'wind_degree': 272,
#   'wind_dir': 'W',
#   'pressure_mb': 1016.0,
#   'pressure_in': 30.0,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 74,
#   'cloud': 26,
#   'feelslike_c': 8.0,
#   'feelslike_f': 46.3,
#   'windchill_c': 8.0,
#   'windchill_f': 46.3,
#   'heatindex_c': 10.0,
#   'heatindex_f': 50.0,
#   'dewpoint_c': 5.5,
#   'dewpoint_f': 42.0,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 12.2,
#   'gust_kph': 19.6,
#   'uv': 4.0},
#  {'time_epoch': 1697270400,
#   'time': '2023-10-14 09:00',
#   'temp_c': 11.2,
#   'temp_f': 52.1,
#   'is_day': 1,
#   'condition': {'text': 'Patchy rain possible',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#    'code': 1063},
#   'wind_mph': 9.8,
#   'wind_kph': 15.8,
#   'wind_degree': 291,
#   'wind_dir': 'WNW',
#   'pressure_mb': 1016.0,
#   'pressure_in': 30.02,
#   'precip_mm': 0.02,
#   'precip_in': 0.0,
#   'humidity': 69,
#   'cloud': 71,
#   'feelslike_c': 9.3,
#   'feelslike_f': 48.7,
#   'windchill_c': 9.3,
#   'windchill_f': 48.7,
#   'heatindex_c': 11.2,
#   'heatindex_f': 52.1,
#   'dewpoint_c': 5.7,
#   'dewpoint_f': 42.2,
#   'will_it_rain': 1,
#   'chance_of_rain': 72,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 12.2,
#   'gust_kph': 19.6,
#   'uv': 3.0},
#  {'time_epoch': 1697274000,
#   'time': '2023-10-14 10:00',
#   'temp_c': 12.0,
#   'temp_f': 53.5,
#   'is_day': 1,
#   'condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#    'code': 1000},
#   'wind_mph': 9.6,
#   'wind_kph': 15.5,
#   'wind_degree': 296,
#   'wind_dir': 'WNW',
#   'pressure_mb': 1017.0,
#   'pressure_in': 30.04,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 62,
#   'cloud': 20,
#   'feelslike_c': 10.3,
#   'feelslike_f': 50.5,
#   'windchill_c': 10.3,
#   'windchill_f': 50.5,
#   'heatindex_c': 12.0,
#   'heatindex_f': 53.5,
#   'dewpoint_c': 4.9,
#   'dewpoint_f': 40.9,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 11.2,
#   'gust_kph': 18.0,
#   'uv': 4.0},
#  {'time_epoch': 1697277600,
#   'time': '2023-10-14 11:00',
#   'temp_c': 12.8,
#   'temp_f': 55.0,
#   'is_day': 1,
#   'condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#    'code': 1000},
#   'wind_mph': 10.1,
#   'wind_kph': 16.2,
#   'wind_degree': 306,
#   'wind_dir': 'NW',
#   'pressure_mb': 1018.0,
#   'pressure_in': 30.05,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 55,
#   'cloud': 24,
#   'feelslike_c': 11.2,
#   'feelslike_f': 52.2,
#   'windchill_c': 11.2,
#   'windchill_f': 52.2,
#   'heatindex_c': 12.8,
#   'heatindex_f': 55.0,
#   'dewpoint_c': 3.9,
#   'dewpoint_f': 39.0,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 11.6,
#   'gust_kph': 18.6,
#   'uv': 4.0},
#  {'time_epoch': 1697281200,
#   'time': '2023-10-14 12:00',
#   'temp_c': 13.4,
#   'temp_f': 56.0,
#   'is_day': 1,
#   'condition': {'text': 'Patchy rain possible',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#    'code': 1063},
#   'wind_mph': 10.5,
#   'wind_kph': 16.9,
#   'wind_degree': 309,
#   'wind_dir': 'NW',
#   'pressure_mb': 1018.0,
#   'pressure_in': 30.06,
#   'precip_mm': 0.01,
#   'precip_in': 0.0,
#   'humidity': 51,
#   'cloud': 66,
#   'feelslike_c': 11.9,
#   'feelslike_f': 53.4,
#   'windchill_c': 11.9,
#   'windchill_f': 53.4,
#   'heatindex_c': 13.4,
#   'heatindex_f': 56.0,
#   'dewpoint_c': 3.5,
#   'dewpoint_f': 38.3,
#   'will_it_rain': 1,
#   'chance_of_rain': 81,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 12.1,
#   'gust_kph': 19.5,
#   'uv': 3.0},
#  {'time_epoch': 1697284800,
#   'time': '2023-10-14 13:00',
#   'temp_c': 13.7,
#   'temp_f': 56.6,
#   'is_day': 1,
#   'condition': {'text': 'Patchy rain possible',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#    'code': 1063},
#   'wind_mph': 10.3,
#   'wind_kph': 16.6,
#   'wind_degree': 309,
#   'wind_dir': 'NW',
#   'pressure_mb': 1018.0,
#   'pressure_in': 30.06,
#   'precip_mm': 0.01,
#   'precip_in': 0.0,
#   'humidity': 48,
#   'cloud': 67,
#   'feelslike_c': 12.3,
#   'feelslike_f': 54.1,
#   'windchill_c': 12.3,
#   'windchill_f': 54.1,
#   'heatindex_c': 13.7,
#   'heatindex_f': 56.6,
#   'dewpoint_c': 2.9,
#   'dewpoint_f': 37.3,
#   'will_it_rain': 1,
#   'chance_of_rain': 83,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 11.8,
#   'gust_kph': 19.0,
#   'uv': 3.0},
#  {'time_epoch': 1697288400,
#   'time': '2023-10-14 14:00',
#   'temp_c': 13.8,
#   'temp_f': 56.8,
#   'is_day': 1,
#   'condition': {'text': 'Patchy rain possible',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#    'code': 1063},
#   'wind_mph': 9.8,
#   'wind_kph': 15.8,
#   'wind_degree': 310,
#   'wind_dir': 'NW',
#   'pressure_mb': 1018.0,
#   'pressure_in': 30.07,
#   'precip_mm': 0.01,
#   'precip_in': 0.0,
#   'humidity': 46,
#   'cloud': 63,
#   'feelslike_c': 12.5,
#   'feelslike_f': 54.5,
#   'windchill_c': 12.5,
#   'windchill_f': 54.5,
#   'heatindex_c': 13.8,
#   'heatindex_f': 56.8,
#   'dewpoint_c': 2.5,
#   'dewpoint_f': 36.5,
#   'will_it_rain': 1,
#   'chance_of_rain': 78,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 11.3,
#   'gust_kph': 18.2,
#   'uv': 3.0},
#  {'time_epoch': 1697292000,
#   'time': '2023-10-14 15:00',
#   'temp_c': 13.5,
#   'temp_f': 56.4,
#   'is_day': 1,
#   'condition': {'text': 'Patchy rain possible',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#    'code': 1063},
#   'wind_mph': 10.3,
#   'wind_kph': 16.6,
#   'wind_degree': 306,
#   'wind_dir': 'NW',
#   'pressure_mb': 1019.0,
#   'pressure_in': 30.08,
#   'precip_mm': 0.01,
#   'precip_in': 0.0,
#   'humidity': 46,
#   'cloud': 56,
#   'feelslike_c': 12.1,
#   'feelslike_f': 53.8,
#   'windchill_c': 12.1,
#   'windchill_f': 53.8,
#   'heatindex_c': 13.5,
#   'heatindex_f': 56.4,
#   'dewpoint_c': 2.3,
#   'dewpoint_f': 36.1,
#   'will_it_rain': 1,
#   'chance_of_rain': 87,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 12.5,
#   'gust_kph': 20.2,
#   'uv': 3.0},
#  {'time_epoch': 1697295600,
#   'time': '2023-10-14 16:00',
#   'temp_c': 13.1,
#   'temp_f': 55.5,
#   'is_day': 1,
#   'condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#    'code': 1000},
#   'wind_mph': 9.6,
#   'wind_kph': 15.5,
#   'wind_degree': 310,
#   'wind_dir': 'NW',
#   'pressure_mb': 1019.0,
#   'pressure_in': 30.09,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 48,
#   'cloud': 20,
#   'feelslike_c': 11.6,
#   'feelslike_f': 53.0,
#   'windchill_c': 11.6,
#   'windchill_f': 53.0,
#   'heatindex_c': 13.1,
#   'heatindex_f': 55.5,
#   'dewpoint_c': 2.3,
#   'dewpoint_f': 36.1,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 12.3,
#   'gust_kph': 19.8,
#   'uv': 4.0},
#  {'time_epoch': 1697299200,
#   'time': '2023-10-14 17:00',
#   'temp_c': 12.2,
#   'temp_f': 54.0,
#   'is_day': 1,
#   'condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#    'code': 1000},
#   'wind_mph': 7.4,
#   'wind_kph': 11.9,
#   'wind_degree': 308,
#   'wind_dir': 'NW',
#   'pressure_mb': 1020.0,
#   'pressure_in': 30.11,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 52,
#   'cloud': 9,
#   'feelslike_c': 11.1,
#   'feelslike_f': 51.9,
#   'windchill_c': 11.1,
#   'windchill_f': 51.9,
#   'heatindex_c': 12.2,
#   'heatindex_f': 54.0,
#   'dewpoint_c': 2.8,
#   'dewpoint_f': 37.0,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 10.2,
#   'gust_kph': 16.5,
#   'uv': 4.0},
#  {'time_epoch': 1697302800,
#   'time': '2023-10-14 18:00',
#   'temp_c': 11.6,
#   'temp_f': 52.8,
#   'is_day': 1,
#   'condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#    'code': 1000},
#   'wind_mph': 6.5,
#   'wind_kph': 10.4,
#   'wind_degree': 312,
#   'wind_dir': 'NW',
#   'pressure_mb': 1020.0,
#   'pressure_in': 30.13,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 56,
#   'cloud': 18,
#   'feelslike_c': 10.4,
#   'feelslike_f': 50.8,
#   'windchill_c': 10.4,
#   'windchill_f': 50.8,
#   'heatindex_c': 11.6,
#   'heatindex_f': 52.8,
#   'dewpoint_c': 3.2,
#   'dewpoint_f': 37.8,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 9.4,
#   'gust_kph': 15.2,
#   'uv': 4.0},
#  {'time_epoch': 1697306400,
#   'time': '2023-10-14 19:00',
#   'temp_c': 9.0,
#   'temp_f': 48.2,
#   'is_day': 0,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#    'code': 1003},
#   'wind_mph': 8.1,
#   'wind_kph': 13.0,
#   'wind_degree': 280,
#   'wind_dir': 'W',
#   'pressure_mb': 1020.0,
#   'pressure_in': 30.12,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 81,
#   'cloud': 25,
#   'feelslike_c': 9.8,
#   'feelslike_f': 49.6,
#   'windchill_c': 9.8,
#   'windchill_f': 49.6,
#   'heatindex_c': 11.0,
#   'heatindex_f': 51.9,
#   'dewpoint_c': 3.4,
#   'dewpoint_f': 38.2,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 9.4,
#   'gust_kph': 15.2,
#   'uv': 1.0},
#  {'time_epoch': 1697310000,
#   'time': '2023-10-14 20:00',
#   'temp_c': 10.6,
#   'temp_f': 51.0,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 6.7,
#   'wind_kph': 10.8,
#   'wind_degree': 306,
#   'wind_dir': 'NW',
#   'pressure_mb': 1021.0,
#   'pressure_in': 30.16,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 62,
#   'cloud': 8,
#   'feelslike_c': 9.2,
#   'feelslike_f': 48.5,
#   'windchill_c': 9.2,
#   'windchill_f': 48.5,
#   'heatindex_c': 10.6,
#   'heatindex_f': 51.0,
#   'dewpoint_c': 3.7,
#   'dewpoint_f': 38.7,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 9.5,
#   'gust_kph': 15.3,
#   'uv': 1.0},
#  {'time_epoch': 1697313600,
#   'time': '2023-10-14 21:00',
#   'temp_c': 10.0,
#   'temp_f': 49.9,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 6.5,
#   'wind_kph': 10.4,
#   'wind_degree': 307,
#   'wind_dir': 'NW',
#   'pressure_mb': 1022.0,
#   'pressure_in': 30.17,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 65,
#   'cloud': 8,
#   'feelslike_c': 8.5,
#   'feelslike_f': 47.3,
#   'windchill_c': 8.5,
#   'windchill_f': 47.3,
#   'heatindex_c': 10.0,
#   'heatindex_f': 49.9,
#   'dewpoint_c': 3.8,
#   'dewpoint_f': 38.8,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 9.2,
#   'gust_kph': 14.8,
#   'uv': 1.0},
#  {'time_epoch': 1697317200,
#   'time': '2023-10-14 22:00',
#   'temp_c': 9.5,
#   'temp_f': 49.1,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 6.5,
#   'wind_kph': 10.4,
#   'wind_degree': 296,
#   'wind_dir': 'WNW',
#   'pressure_mb': 1022.0,
#   'pressure_in': 30.19,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 67,
#   'cloud': 12,
#   'feelslike_c': 8.0,
#   'feelslike_f': 46.3,
#   'windchill_c': 8.0,
#   'windchill_f': 46.3,
#   'heatindex_c': 9.5,
#   'heatindex_f': 49.1,
#   'dewpoint_c': 3.8,
#   'dewpoint_f': 38.8,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 9.2,
#   'gust_kph': 14.8,
#   'uv': 1.0},
#  {'time_epoch': 1697320800,
#   'time': '2023-10-14 23:00',
#   'temp_c': 9.1,
#   'temp_f': 48.3,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 6.7,
#   'wind_kph': 10.8,
#   'wind_degree': 295,
#   'wind_dir': 'WNW',
#   'pressure_mb': 1023.0,
#   'pressure_in': 30.2,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 69,
#   'cloud': 10,
#   'feelslike_c': 7.4,
#   'feelslike_f': 45.3,
#   'windchill_c': 7.4,
#   'windchill_f': 45.3,
#   'heatindex_c': 9.1,
#   'heatindex_f': 48.3,
#   'dewpoint_c': 3.8,
#   'dewpoint_f': 38.9,
#   'will_it_rain': 0,
#   'chance_of_rain': 0,
#   'will_it_snow': 0,
#   'chance_of_snow': 0,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'gust_mph': 9.5,
#   'gust_kph': 15.2,
#   'uv': 1.0}]

# %% [markdown]
# The final 0 is 0:00 AM, as we have observed that it has 24 segments within the hour

# %%
response['forecast']['forecastday'][0]['hour'][0]
# Out:
# {'time_epoch': 1697238000,
#  'time': '2023-10-14 00:00',
#  'temp_c': 10.5,
#  'temp_f': 50.8,
#  'is_day': 0,
#  'condition': {'text': 'Clear',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#   'code': 1000},
#  'wind_mph': 12.5,
#  'wind_kph': 20.2,
#  'wind_degree': 294,
#  'wind_dir': 'WNW',
#  'pressure_mb': 1008.0,
#  'pressure_in': 29.78,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 75,
#  'cloud': 2,
#  'feelslike_c': 8.0,
#  'feelslike_f': 46.3,
#  'windchill_c': 8.0,
#  'windchill_f': 46.3,
#  'heatindex_c': 10.5,
#  'heatindex_f': 50.8,
#  'dewpoint_c': 6.2,
#  'dewpoint_f': 43.2,
#  'will_it_rain': 0,
#  'chance_of_rain': 0,
#  'will_it_snow': 0,
#  'chance_of_snow': 0,
#  'vis_km': 10.0,
#  'vis_miles': 6.0,
#  'gust_mph': 17.8,
#  'gust_kph': 28.7,
#  'uv': 1.0}

# %% [markdown]
# We see in the response that the 'time' field contains the time, to view it:

# %%
response['forecast']['forecastday'][0]['hour'][0]['time']
# Out:
# '2023-10-14 00:00'

# %% [markdown]
# As we want to split it, we use 'split' since it is a string, the '0' in square brackets at the end is to indicate that we want the first position of the split

# %%
response['forecast']['forecastday'][0]['hour'][0]['time'].split()[0] # Date (in yyyy - mm - dd format)
# Out:
# '2023-10-14'

# %% [markdown]
# To get the hour, we take the second position (1), perform a new split indicating that we want to separate by colons ':', and we keep position 0 (the hour)

# %%
response['forecast']['forecastday'][0]['hour'][1]['time'].split()[1].split(':')[0]
# Out:
# '01'

# %% [markdown]
# We convert it to an integer, so we do the same by adding int

# %%
int(response['forecast']['forecastday'][0]['hour'][1]['time'].split()[1].split(':')[0]) # Time of day (integer)
# Out:
# 1

# %% [markdown]
# Now we want to focus on the alerts that it may rain, we explore 'condition' within 'hours

# %%
response['forecast']['forecastday'][0]['hour'][0]['condition']
# Out:
# {'text': 'Clear',
#  'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#  'code': 1000}

# %%
response['forecast']['forecastday'][0]['hour'][0]['condition']['text'] # Weather condition
# Out:
# 'Clear'

# %% [markdown]
# Now the temperature

# %%
response['forecast']['forecastday'][0]['hour'][0]['temp_c'] # Temperature in ºC
# Out:
# 10.5

# %% [markdown]
# To find out whether it will rain or not, there is the 'will it rain' field

# %%
response['forecast']['forecastday'][0]['hour'][0]['will_it_rain'] # Will it rain? 0 is no, 1 is likely
# Out:
# 0

# %%
response['forecast']['forecastday'][0]['hour'][2]['chance_of_rain'] # probability of rain
# Out:
# 0

# %% [markdown]
# # Dataframe creation

# %%
def get_forecast(response,i):

    date = response['forecast']['forecastday'][0]['hour'][i]['time'].split()[0]
    hour = int(response['forecast']['forecastday'][0]['hour'][i]['time'].split()[1].split(':')[0])
    condition = response['forecast']['forecastday'][0]['hour'][i]['condition']['text']
    tempe = response['forecast']['forecastday'][0]['hour'][i]['temp_c']
    rain = response['forecast']['forecastday'][0]['hour'][i]['will_it_rain']
    chance_rain = response['forecast']['forecastday'][0]['hour'][i]['chance_of_rain']

    return date,hour,condition,tempe,rain,chance_rain

# %%
data = []

for i in tqdm(range(len(response['forecast']['forecastday'][0]['hour'])),colour = 'green'):
    
    data.append(get_forecast(response,i))
# Out:
# 100%|██████████| 24/24 [00:00<00:00, 23984.58it/s]

# %%
def create_df(data):

    col = ['Date','Hour','Condition','Temperature','Rain','Chance_of_rain']
    df = pd.DataFrame(data,columns=col)
    df = df.sort_values(by = 'Hour',ascending = True)

    df_rain = df[(df['Rain']==1) & (df['Time']>=6) & (df['Time']<= 22)]
    df_rain = df_rain[['Hour','Condition']]
    df_rain.set_index('Hour', inplace = True)

    return df_rain

# %%
col = ['Date','Hour','Condition','Temperature','Rain','Chance_of_rain']
df = pd.DataFrame(data,columns=col)
#df = df.sort_values(by='Hour',ascending = True)
df
# Out:
#           Date  Hour             Condition  Temperature  Rain  Chance_of_rain
# 0   2023-10-14     0                 Clear         10.5     0               0
# 1   2023-10-14     1                 Clear         10.2     0               0
# 2   2023-10-14     2                 Clear         10.0     0               0
# 3   2023-10-14     3                 Clear          9.8     0               0
# 4   2023-10-14     4                 Clear          9.7     0               0
# 5   2023-10-14     5                 Clear          9.4     0               0
# 6   2023-10-14     6                 Clear          9.3     0               0
# 7   2023-10-14     7                 Clear          9.3     0               0
# 8   2023-10-14     8         Partly cloudy         10.0     0               0
# 9   2023-10-14     9  Patchy rain possible         11.2     1              72
# 10  2023-10-14    10                 Sunny         12.0     0               0
# 11  2023-10-14    11                 Sunny         12.8     0               0
# 12  2023-10-14    12  Patchy rain possible         13.4     1              81
# 13  2023-10-14    13  Patchy rain possible         13.7     1              83
# 14  2023-10-14    14  Patchy rain possible         13.8     1              78
# 15  2023-10-14    15  Patchy rain possible         13.5     1              87
# 16  2023-10-14    16                 Sunny         13.1     0               0
# 17  2023-10-14    17                 Sunny         12.2     0               0
# 18  2023-10-14    18                 Sunny         11.6     0               0
# 19  2023-10-14    19         Partly cloudy          9.0     0               0
# 20  2023-10-14    20                 Clear         10.6     0               0
# 21  2023-10-14    21                 Clear         10.0     0               0
# 22  2023-10-14    22                 Clear          9.5     0               0
# 23  2023-10-14    23                 Clear          9.1     0               0

# %% [markdown]
# We keep the hours when it rains between 6 AM and 10 PM and their conditions. We sort by hour

# %%
df_rain =  df[(df['Rain']==1) & (df['Hour']>=6) & (df['Hour']<= 22)]
df_rain = df_rain[['Hour','Condition']]
df_rain.set_index('Hour', inplace = True)
df_rain
# Out:
#                  Condition
# Hour
# 9     Patchy rain possible
# 12    Patchy rain possible
# 13    Patchy rain possible
# 14    Patchy rain possible
# 15    Patchy rain possible

# %% [markdown]
# # SMS Message from Twilio

# %%
data[0][0]
# Out:
# '2023-10-14'

# %%
time.sleep(2)
account_sid = 'YOUR TWILIO SID' # !!!
auth_token = 'YOUR TWILIO TOKEN' # !!!

client = Client(account_sid, auth_token)

message = client.messages \
                .create(
                    body='\nHi! \n\n\nToday\'s '+ data[0][0] + ' rain forecast in ' + query +' is:\n\n\n' + str(df_rain),
                    from_='YOUR TWILIO NUMBER', # !!!
                    to='YOUR NUMBER' # !!!
                 )

print('Message Sent ' + message.sid)
# Out:
# Message Sent SMd21303fb605fc6305c66b949b8ab3bda
